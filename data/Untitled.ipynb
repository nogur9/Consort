# %%
# Started therapy count

# %%
started_therapy_count = {
    "משתתפים פעילים" : 0,
    "פספוסי גיוסים" : 0,
    'אין שת"פ טיפולי': 5,
    "אי התאמה למחקר": 3,
    "אי הסכמה למחקר": 4,
    "CAU": 1,
    "IPC-SSC": 10,
    "סיימו טיפול": 0,
    "נשירה מחקרית": 10,
    "נשירה קלינית- לאחר ת. טיפול": 10,
    "עלייה לרמה 2": 2}

# %%
for i, j in started_therapy_count.items():print (f"{i} = {j}")
# Out:
# משתתפים פעילים = 0
# פספוסי גיוסים = 0
# אין שת"פ טיפולי = 5
# אי התאמה למחקר = 3
# אי הסכמה למחקר = 4
# CAU = 1
# IPC-SSC = 10
# סיימו טיפול = 0
# נשירה מחקרית = 10
# נשירה קלינית- לאחר ת. טיפול = 10
# עלייה לרמה 2 = 2
