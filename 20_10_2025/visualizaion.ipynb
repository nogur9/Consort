# %%
import pandas as pd

# %%
df = pd.read_excel(r"../data/export_with_days_delta _051025_,תיקונים.xlsx")

# %%
consort_groups = [   
    'N',
    'Eligible',
    'Randomized',
    'Dropout',
    'Research Dropout',
    'Clinical Dropout',
    'In Waiting List',
    'Finished',
    'Active',
    'Not Cooperative'
]

# %%
values = {'count': (sum?), 'waiting_duration': mean, 'did_started_therapy': 'mean', 'did_started_therapy': mean, 'suiteable_for_pp': mean}

# %%
groups = 'group'
